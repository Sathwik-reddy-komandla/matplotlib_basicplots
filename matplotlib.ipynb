# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=["Item1","Item2","Item3"]


plt.pie(x,labels=y,autopct="%0.2f%%")

plt.show()

# %%
x=list(range(10))
y=[i%3 for i in x]
y
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2, 0]

# %%
plt.scatter(x,y,color='red',marker='D')

# %%
plt.plot(x,y,color='pink',marker='D')

# %%
x=[2012,2013,2014,2015,2016,2017,2018,2019,2020]
y=[65000,69000,70000,75000,55000,50000,64000,81000,90000]

# %%
plt.barh(x,y,color='red')
# plt.bar(x,y,color='blue')
plt.ylabel("Price in INR")
plt.xlabel("Year")
plt.title("Year by Year Price Comp")
# Out:
# Text(0.5, 1.0, 'Year by Year Price Comp')
